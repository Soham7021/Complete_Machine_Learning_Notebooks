# %% [markdown]
# # GO TO RAPID API AND GET THE DATA AND DO THE FOLLOWING

# %%
# THE LINK FOR RAPID API : https://rapidapi.com/hub

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
	"X-RapidAPI-Key": "5ccf09b649msh3fa5381ae020f79p18ed58jsn73e7e29b739d",
	"X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# %%
print(response.json())
# Out:
# [{'rank': 1, 'title': 'The Shawshank Redemption', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg', 'rating': '9.3', 'id': 'top1', 'year': 1994, 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'description': 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 'trailer': 'https://www.youtube.com/embed/NmzuHjWmXOc', 'genre': ['Drama'], 'director': ['Frank Darabont'], 'writers': ['Stephen King (based on the short novel "Rita Hayworth and the Shawshank Redemption" by)', 'Frank Darabont (screenplay by)'], 'imdbid': 'tt0111161'}, {'rank': 2, 'title': 'The Godfather', 'thumbnail': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V
# ...

# %%
pd.DataFrame(response.json()).head(2)
# Out:
#    rank                     title  \
# 0     1  The Shawshank Redemption
# 1     2             The Godfather
#
#                                            thumbnail rating    id  year  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...    9.3  top1  1994
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...    9.2  top2  1972
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                                          description  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
#
#                                      trailer           genre  \
# 0  https://www.youtube.com/embed/NmzuHjWmXOc         [Drama]
# 1  https://www.youtube.com/embed/rqGJyUB1Q3s  [Crime, Drama]
#
#                  director                                            writers  \
# ...

# %%
temp_df = pd.DataFrame(response.json())

# %%
temp_df
# Out:
#     rank                     title  \
# 0      1  The Shawshank Redemption
# 1      2             The Godfather
# 2      3           The Dark Knight
# 3      4     The Godfather Part II
# 4      5              12 Angry Men
# ..   ...                       ...
# 95    96        Lawrence of Arabia
# 96    97                         M
# 97    98              Come and See
# 98    99        North by Northwest
# 99   100                   Vertigo
#
#                                             thumbnail rating      id  year  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...    9.3    top1  1994
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...    9.2    top2  1972
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...    9.0    top3  2008
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...    9.0    top4  1974
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...    9.0    top5  1957
# ..                                                ...    ...     ...   ...
# ...

# %%
dft = pd.DataFrame()

# %%
dft
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,98):
    response = requests.get('https://imdb-top-100-movies.p.rapidapi.com/')
    temp_df = pd.DataFrame(response.json())
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
#       1 for i in range(1,98):
#       2     response = requests.get('https://imdb-top-100-movies.p.rapidapi.com/')
# ----> 3     temp_df = pd.DataFrame(response.json())
#       4     df = df.append(temp_df,ignore_index=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
# ...

# %%
dft

# %%
temp_df.to_csv('Live_Sports_Odds.csv')

# %%
temp_dff = pd.read_json('cricketRecords.json')

# %%
temp_dff
# Out:
#                                                  feeds  totalFeed
# 0    {'id': 2140, 'title': 'gj', 'description': 'gh...        125
# 1    {'id': 2139, 'title': 'dfg', 'description': 'd...        125
# 2    {'id': 2138, 'title': 'TEst Video', 'descripti...        125
# 3    {'id': 2137, 'title': 'QQ', 'description': 'qq...        125
# 4    {'id': 2136, 'title': 'gj', 'description': 'gh...        125
# ..                                                 ...        ...
# 495  {'id': 53, 'title': 'new one', 'description': ...        125
# 496  {'id': 52, 'title': 'new one', 'description': ...        125
# 497  {'id': 51, 'title': 'ssfdfd', 'description': '...        125
# 498  {'id': 50, 'title': 'Test Code', 'description'...        125
# 499  {'id': 49, 'title': 'A mobile phone is a wirel...        125
#
# [500 rows x 2 columns]

# %%
daf = temp_dff.to_csv('cricketRecords.csv')

# %%
import json
import csv
with open("cricketRecords.json") as file:
    data = json.load(file)
    
fname = "cricketRecords.csv"
with open(fname,'w') as file:
    csv_file = csv.writer(file)
    csv_file.writerow(["id","title","userId","name","profilePicture"])
    for item in data["feeds"]:
        csv_file.writerow([item['id'],item['title'],item['userId'],item['name'],item['profilePicture']])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [89], in <cell line: 3>()
#       2 import csv
#       3 with open("cricketRecords.json") as file:
# ----> 4     data = json.load(file)
#       6 fname = "cricketRecords.csv"
#       7 with open(fname,'w') as file:
#
# File ~\anaconda3\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
# ...
